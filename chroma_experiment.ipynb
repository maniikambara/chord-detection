# %%
from load import LABELS, load_feature
from cnn import run_pipeline

# %%
train_x, train_y, label_encoder = load_feature("train","chroma_cache")
val_x, val_y = load_feature("val", "chroma_cache", label_encoder)
test_x, test_y = load_feature("test", "chroma_cache", label_encoder)

# %%
run_pipeline(
    train_x, train_y,
    val_x,   val_y,
    test_x,  test_y,
    labels=LABELS,
    epochs=30,
    patience=10,
    batch_size=32,
    scenario = "chroma"
)
# Out:
# Number of classes: 48
# Using device: cuda
# train_x shape: torch.Size([30239, 1, 12, 126])
# CNNModel(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.1, inplace=False)
#     (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.2, inplace=False)
#     (10): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.25, inplace=False)
#     (15): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU()
#     (18): AdaptiveAvgPool2d(output_size=(4, 4))
#     (19): Dropout(p=0.3, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=4096, out_features=512, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.3, inplace=False)
#     (7): Linear(in_features=256, out_features=48, bias=True)
#   )
# )
#
# Epoch [1/30]
#   Train | Loss: 1.2468  Acc: 0.8654
#   Val   | Loss: 0.8026  Acc: 0.9991
#   Best model saved
#
# Epoch [2/30]
#   Train | Loss: 0.8780  Acc: 0.9916
#   Val   | Loss: 0.8044  Acc: 0.9998
#
# Epoch [3/30]
#   Train | Loss: 0.8473  Acc: 0.9961
#   Val   | Loss: 0.7813  Acc: 0.9991
#   Best model saved
#
# Epoch [4/30]
#   Train | Loss: 0.8255  Acc: 0.9974
#   Val   | Loss: 0.7296  Acc: 0.9998
#   Best model saved
#
# Epoch [5/30]
#   Train | Loss: 0.8099  Acc: 0.9983
#   Val   | Loss: 0.7337  Acc: 0.9998
#
# Epoch [6/30]
#   Train | Loss: 0.7914  Acc: 0.9989
#   Val   | Loss: 0.7270  Acc: 0.9991
#   Best model saved
#
# Epoch [7/30]
#   Train | Loss: 0.7712  Acc: 0.9996
#   Val   | Loss: 0.7171  Acc: 0.9998
#   Best model saved
#
# Epoch [8/30]
#   Train | Loss: 0.7527  Acc: 0.9994
#   Val   | Loss: 0.7079  Acc: 1.0000
#   Best model saved
#
# Epoch [9/30]
#   Train | Loss: 0.7413  Acc: 0.9998
#   Val   | Loss: 0.7050  Acc: 1.0000
#   Best model saved
#
# Epoch [10/30]
#   Train | Loss: 0.7429  Acc: 0.9994
#   Val   | Loss: 0.7057  Acc: 0.9995
#
# Epoch [11/30]
#   Train | Loss: 0.7403  Acc: 0.9994
#   Val   | Loss: 0.7052  Acc: 1.0000
#
# Epoch [12/30]
#   Train | Loss: 0.7389  Acc: 0.9994
#   Val   | Loss: 0.7053  Acc: 0.9998
#
# Epoch [13/30]
#   Train | Loss: 0.7353  Acc: 0.9996
#   Val   | Loss: 0.7043  Acc: 1.0000
#   Best model saved
#
# Epoch [14/30]
#   Train | Loss: 0.7350  Acc: 0.9996
#   Val   | Loss: 0.7022  Acc: 1.0000
#   Best model saved
#
# Epoch [15/30]
#   Train | Loss: 0.7355  Acc: 0.9994
#   Val   | Loss: 0.7039  Acc: 1.0000
#
# Epoch [16/30]
#   Train | Loss: 0.7325  Acc: 0.9999
#   Val   | Loss: 0.7026  Acc: 1.0000
#
# Epoch [17/30]
#   Train | Loss: 0.7319  Acc: 0.9998
#   Val   | Loss: 0.7039  Acc: 1.0000
#
# Epoch [18/30]
#   Train | Loss: 0.7309  Acc: 0.9998
#   Val   | Loss: 0.7017  Acc: 1.0000
#   Best model saved
#
# Epoch [19/30]
#   Train | Loss: 0.7319  Acc: 0.9996
#   Val   | Loss: 0.7035  Acc: 1.0000
#
# Epoch [20/30]
#   Train | Loss: 0.7307  Acc: 0.9997
#   Val   | Loss: 0.7008  Acc: 1.0000
#   Best model saved
#
# Epoch [21/30]
#   Train | Loss: 0.7291  Acc: 0.9998
#   Val   | Loss: 0.7031  Acc: 1.0000
#
# Epoch [22/30]
#   Train | Loss: 0.7286  Acc: 0.9999
#   Val   | Loss: 0.7026  Acc: 1.0000
#
# Epoch [23/30]
#   Train | Loss: 0.7289  Acc: 0.9999
#   Val   | Loss: 0.7022  Acc: 1.0000
#
# Epoch [24/30]
#   Train | Loss: 0.7272  Acc: 1.0000
#   Val   | Loss: 0.7006  Acc: 1.0000
#   Best model saved
#
# Epoch [25/30]
#   Train | Loss: 0.7298  Acc: 0.9996
#   Val   | Loss: 0.7034  Acc: 1.0000
#
# Epoch [26/30]
#   Train | Loss: 0.7267  Acc: 1.0000
#   Val   | Loss: 0.7011  Acc: 1.0000
#
# Epoch [27/30]
#   Train | Loss: 0.7266  Acc: 0.9999
#   Val   | Loss: 0.7019  Acc: 1.0000
#
# Epoch [28/30]
#   Train | Loss: 0.7283  Acc: 0.9998
#   Val   | Loss: 0.7051  Acc: 1.0000
#
# Epoch [29/30]
#   Train | Loss: 0.7273  Acc: 0.9998
#   Val   | Loss: 0.7012  Acc: 1.0000
#
# Epoch [30/30]
#   Train | Loss: 0.7254  Acc: 1.0000
#   Val   | Loss: 0.7014  Acc: 1.0000
#
# ========================================
# Test Accuracy : 1.0000
# Test Loss     : 0.7006
# Precision     : 1.0000
# Recall        : 1.0000
# F1 Score      : 1.0000
# ========================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       180
#            1       1.00      1.00      1.00       180
#            2       1.00      1.00      1.00       180
#            3       1.00      1.00      1.00       180
#            4       1.00      1.00      1.00       180
#            5       1.00      1.00      1.00       180
#            6       1.00      1.00      1.00       180
#            7       1.00      1.00      1.00       180
#            8       1.00      1.00      1.00       180
#            9       1.00      1.00      1.00       180
#           10       1.00      1.00      1.00       180
#           11       1.00      1.00      1.00       180
#           12       1.00      1.00      1.00       180
#           13       1.00      1.00      1.00       180
#           14       1.00      1.00      1.00       180
#           15       1.00      1.00      1.00       180
#           16       1.00      1.00      1.00       180
#           17       1.00      1.00      1.00       180
#           18       1.00      1.00      1.00       180
#           19       1.00      1.00      1.00       180
#           20       1.00      1.00      1.00       180
#           21       1.00      1.00      1.00       180
#           22       1.00      1.00      1.00       180
#           23       1.00      1.00      1.00       180
#           24       1.00      1.00      1.00       180
#           25       1.00      1.00      1.00       180
#           26       1.00      1.00      1.00       180
#           27       1.00      1.00      1.00       180
#           28       1.00      1.00      1.00       180
#           29       1.00      1.00      1.00       180
#           30       1.00      1.00      1.00       180
#           31       1.00      1.00      1.00       180
#           32       1.00      1.00      1.00       180
#           33       1.00      1.00      1.00       180
#           34       1.00      1.00      1.00       180
#           35       1.00      1.00      1.00       180
#           36       1.00      1.00      1.00       180
#           37       1.00      1.00      1.00       180
#           38       1.00      1.00      1.00       181
#           39       1.00      1.00      1.00       180
#           40       1.00      1.00      1.00       180
#           41       1.00      1.00      1.00       180
#           42       1.00      1.00      1.00       180
#           43       1.00      1.00      1.00       180
#           44       1.00      1.00      1.00       180
#           45       1.00      1.00      1.00       180
#           46       1.00      1.00      1.00       180
#           47       1.00      1.00      1.00       180
#
#     accuracy                           1.00      8641
#    macro avg       1.00      1.00      1.00      8641
# weighted avg       1.00      1.00      1.00      8641
