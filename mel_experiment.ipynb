# %%
from load import LABELS, load_feature
from cnn import run_pipeline

# %%
train_x, train_y, label_encoder = load_feature("train","mel_cache")
val_x, val_y = load_feature("val", "mel_cache", label_encoder)
test_x, test_y = load_feature("test", "mel_cache", label_encoder)

# %%
run_pipeline(
    train_x, train_y,
    val_x,   val_y,
    test_x,  test_y,
    labels=LABELS,
    epochs=30,
    patience=10,
    batch_size=32,
    scenario = "mel"
)
# Out:
# Using device: cuda
# train_x shape: torch.Size([30239, 1, 128, 126])
# Number of classes: 48
# CNNModel(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): AdaptiveAvgPool2d(output_size=(4, 4))
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=4096, out_features=512, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.3, inplace=False)
#     (7): Linear(in_features=256, out_features=48, bias=True)
#   )
# )
#
# Epoch [1/30]
#   Train — Loss: 2.7127  Acc: 0.3405
#   Val   — Loss: 1.0563  Acc: 0.9634
#   ✓ Best model saved
#
# Epoch [2/30]
#   Train — Loss: 1.2984  Acc: 0.8543
#   Val   — Loss: 0.8463  Acc: 0.9935
#   ✓ Best model saved
#
# Epoch [3/30]
#   Train — Loss: 1.0986  Acc: 0.9242
#   Val   — Loss: 0.8451  Acc: 0.9944
#   ✓ Best model saved
#
# Epoch [4/30]
#   Train — Loss: 1.0290  Acc: 0.9425
#   Val   — Loss: 0.8242  Acc: 0.9993
#   ✓ Best model saved
#
# Epoch [5/30]
#   Train — Loss: 0.9795  Acc: 0.9547
#   Val   — Loss: 0.7880  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [6/30]
#   Train — Loss: 0.9430  Acc: 0.9630
#   Val   — Loss: 0.7914  Acc: 1.0000
#
# Epoch [7/30]
#   Train — Loss: 0.9181  Acc: 0.9678
#   Val   — Loss: 0.7682  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [8/30]
#   Train — Loss: 0.8992  Acc: 0.9722
#   Val   — Loss: 0.7634  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [9/30]
#   Train — Loss: 0.8844  Acc: 0.9737
#   Val   — Loss: 0.7556  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [10/30]
#   Train — Loss: 0.8693  Acc: 0.9765
#   Val   — Loss: 0.7536  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [11/30]
#   Train — Loss: 0.8608  Acc: 0.9782
#   Val   — Loss: 0.7479  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [12/30]
#   Train — Loss: 0.8528  Acc: 0.9790
#   Val   — Loss: 0.7419  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [13/30]
#   Train — Loss: 0.8476  Acc: 0.9790
#   Val   — Loss: 0.7434  Acc: 1.0000
#
# Epoch [14/30]
#   Train — Loss: 0.8414  Acc: 0.9813
#   Val   — Loss: 0.7348  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [15/30]
#   Train — Loss: 0.8323  Acc: 0.9829
#   Val   — Loss: 0.7300  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [16/30]
#   Train — Loss: 0.8326  Acc: 0.9826
#   Val   — Loss: 0.7390  Acc: 1.0000
#
# Epoch [17/30]
#   Train — Loss: 0.8282  Acc: 0.9833
#   Val   — Loss: 0.7252  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [18/30]
#   Train — Loss: 0.8235  Acc: 0.9847
#   Val   — Loss: 0.7198  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [19/30]
#   Train — Loss: 0.8231  Acc: 0.9842
#   Val   — Loss: 0.7217  Acc: 1.0000
#
# Epoch [20/30]
#   Train — Loss: 0.8171  Acc: 0.9853
#   Val   — Loss: 0.7252  Acc: 1.0000
#
# Epoch [21/30]
#   Train — Loss: 0.8136  Acc: 0.9870
#   Val   — Loss: 0.7214  Acc: 1.0000
#
# Epoch [22/30]
#   Train — Loss: 0.8125  Acc: 0.9864
#   Val   — Loss: 0.7201  Acc: 1.0000
#
# Epoch [23/30]
#   Train — Loss: 0.8063  Acc: 0.9889
#   Val   — Loss: 0.7170  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [24/30]
#   Train — Loss: 0.8101  Acc: 0.9880
#   Val   — Loss: 0.7223  Acc: 1.0000
#
# Epoch [25/30]
#   Train — Loss: 0.8059  Acc: 0.9883
#   Val   — Loss: 0.7216  Acc: 1.0000
#
# Epoch [26/30]
#   Train — Loss: 0.8032  Acc: 0.9896
#   Val   — Loss: 0.7169  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [27/30]
#   Train — Loss: 0.8049  Acc: 0.9882
#   Val   — Loss: 0.7180  Acc: 1.0000
#
# Epoch [28/30]
#   Train — Loss: 0.8008  Acc: 0.9896
#   Val   — Loss: 0.7174  Acc: 1.0000
#
# Epoch [29/30]
#   Train — Loss: 0.8014  Acc: 0.9898
#   Val   — Loss: 0.7152  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [30/30]
#   Train — Loss: 0.7984  Acc: 0.9905
#   Val   — Loss: 0.7147  Acc: 1.0000
#   ✓ Best model saved
#
# ========================================
# Test Accuracy : 1.0000
# Test Loss     : 0.7147
# Precision     : 1.0000
# Recall        : 1.0000
# F1 Score      : 1.0000
# ========================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Af_a       1.00      1.00      1.00       180
#         Af_d       1.00      1.00      1.00       180
#         Af_j       1.00      1.00      1.00       180
#         Af_n       1.00      1.00      1.00       180
#         An_a       1.00      1.00      1.00       180
#         An_d       1.00      1.00      1.00       180
#         An_j       1.00      1.00      1.00       180
#         An_n       1.00      1.00      1.00       180
#         Bf_a       1.00      1.00      1.00       180
#         Bf_d       1.00      1.00      1.00       180
#         Bf_j       1.00      1.00      1.00       180
#         Bf_n       1.00      1.00      1.00       180
#         Bn_a       1.00      1.00      1.00       180
#         Bn_d       1.00      1.00      1.00       180
#         Bn_j       1.00      1.00      1.00       180
#         Bn_n       1.00      1.00      1.00       180
#         Cn_a       1.00      1.00      1.00       180
#         Cn_d       1.00      1.00      1.00       180
#         Cn_j       1.00      1.00      1.00       180
#         Cn_n       1.00      1.00      1.00       180
#         Df_a       1.00      1.00      1.00       180
#         Df_d       1.00      1.00      1.00       180
#         Df_j       1.00      1.00      1.00       180
#         Df_n       1.00      1.00      1.00       180
#         Dn_a       1.00      1.00      1.00       180
#         Dn_d       1.00      1.00      1.00       180
#         Dn_j       1.00      1.00      1.00       180
#         Dn_n       1.00      1.00      1.00       180
#         Ef_a       1.00      1.00      1.00       180
#         Ef_d       1.00      1.00      1.00       180
#         Ef_j       1.00      1.00      1.00       180
#         Ef_n       1.00      1.00      1.00       180
#         En_a       1.00      1.00      1.00       180
#         En_d       1.00      1.00      1.00       180
#         En_j       1.00      1.00      1.00       180
#         En_n       1.00      1.00      1.00       180
#         Fn_a       1.00      1.00      1.00       180
#         Fn_d       1.00      1.00      1.00       180
#         Fn_j       1.00      1.00      1.00       181
#         Fn_n       1.00      1.00      1.00       180
#         Gf_a       1.00      1.00      1.00       180
#         Gf_d       1.00      1.00      1.00       180
#         Gf_j       1.00      1.00      1.00       180
#         Gf_n       1.00      1.00      1.00       180
#         Gn_a       1.00      1.00      1.00       180
#         Gn_d       1.00      1.00      1.00       180
#         Gn_j       1.00      1.00      1.00       180
#         Gn_n       1.00      1.00      1.00       180
#
#     accuracy                           1.00      8641
#    macro avg       1.00      1.00      1.00      8641
# weighted avg       1.00      1.00      1.00      8641
