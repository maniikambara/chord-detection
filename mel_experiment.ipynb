# %%
from load import LABELS, load_feature
from cnn import run_pipeline

# %%
train_x, train_y, label_encoder = load_feature("train","mel_cache")
val_x, val_y = load_feature("val", "mel_cache", label_encoder)
test_x, test_y = load_feature("test", "mel_cache", label_encoder)

# %%
run_pipeline(
    train_x, train_y,
    val_x,   val_y,
    test_x,  test_y,
    labels=LABELS,
    epochs=30,
    patience=10,
    batch_size=32,
    scenario = "mel"
)
# Out:
# Using device: cuda
# train_x shape: torch.Size([30239, 1, 128, 126])
# Number of classes: 48
# CNNModel(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.1, inplace=False)
#     (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.2, inplace=False)
#     (10): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.25, inplace=False)
#     (15): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU()
#     (18): AdaptiveAvgPool2d(output_size=(4, 4))
#     (19): Dropout(p=0.3, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=4096, out_features=512, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.3, inplace=False)
#     (7): Linear(in_features=256, out_features=48, bias=True)
#   )
# )
#
# Epoch [1/30]
#   Train — Loss: 1.9854  Acc: 0.6083
#   Val   — Loss: 0.8026  Acc: 0.9998
#   ✓ Best model saved
#
# Epoch [2/30]
#   Train — Loss: 1.0432  Acc: 0.9486
#   Val   — Loss: 0.7536  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [3/30]
#   Train — Loss: 0.9591  Acc: 0.9671
#   Val   — Loss: 0.7462  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [4/30]
#   Train — Loss: 0.9124  Acc: 0.9758
#   Val   — Loss: 0.7700  Acc: 1.0000
#
# Epoch [5/30]
#   Train — Loss: 0.8881  Acc: 0.9788
#   Val   — Loss: 0.7693  Acc: 1.0000
#
# Epoch [6/30]
#   Train — Loss: 0.8786  Acc: 0.9790
#   Val   — Loss: 0.7624  Acc: 1.0000
#
# Epoch [7/30]
#   Train — Loss: 0.8563  Acc: 0.9845
#   Val   — Loss: 0.7719  Acc: 1.0000
#
# Epoch [8/30]
#   Train — Loss: 0.8459  Acc: 0.9837
#   Val   — Loss: 0.7529  Acc: 1.0000
#
# Epoch [9/30]
#   Train — Loss: 0.8372  Acc: 0.9851
#   Val   — Loss: 0.7340  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [10/30]
#   Train — Loss: 0.8215  Acc: 0.9883
#   Val   — Loss: 0.7443  Acc: 1.0000
#
# Epoch [11/30]
#   Train — Loss: 0.8157  Acc: 0.9893
#   Val   — Loss: 0.7251  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [12/30]
#   Train — Loss: 0.8036  Acc: 0.9907
#   Val   — Loss: 0.7193  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [13/30]
#   Train — Loss: 0.8015  Acc: 0.9902
#   Val   — Loss: 0.7148  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [14/30]
#   Train — Loss: 0.7913  Acc: 0.9926
#   Val   — Loss: 0.7138  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [15/30]
#   Train — Loss: 0.7878  Acc: 0.9930
#   Val   — Loss: 0.7111  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [16/30]
#   Train — Loss: 0.7859  Acc: 0.9936
#   Val   — Loss: 0.7099  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [17/30]
#   Train — Loss: 0.7792  Acc: 0.9940
#   Val   — Loss: 0.7097  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [18/30]
#   Train — Loss: 0.7807  Acc: 0.9928
#   Val   — Loss: 0.7116  Acc: 1.0000
#
# Epoch [19/30]
#   Train — Loss: 0.7771  Acc: 0.9936
#   Val   — Loss: 0.7070  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [20/30]
#   Train — Loss: 0.7771  Acc: 0.9938
#   Val   — Loss: 0.7076  Acc: 1.0000
#
# Epoch [21/30]
#   Train — Loss: 0.7723  Acc: 0.9949
#   Val   — Loss: 0.7064  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [22/30]
#   Train — Loss: 0.7716  Acc: 0.9947
#   Val   — Loss: 0.7073  Acc: 1.0000
#
# Epoch [23/30]
#   Train — Loss: 0.7713  Acc: 0.9946
#   Val   — Loss: 0.7059  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [24/30]
#   Train — Loss: 0.7684  Acc: 0.9958
#   Val   — Loss: 0.7069  Acc: 1.0000
#
# Epoch [25/30]
#   Train — Loss: 0.7666  Acc: 0.9957
#   Val   — Loss: 0.7045  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [26/30]
#   Train — Loss: 0.7667  Acc: 0.9954
#   Val   — Loss: 0.7040  Acc: 1.0000
#   ✓ Best model saved
#
# Epoch [27/30]
#   Train — Loss: 0.7644  Acc: 0.9960
#   Val   — Loss: 0.7045  Acc: 1.0000
#
# Epoch [28/30]
#   Train — Loss: 0.7623  Acc: 0.9969
#   Val   — Loss: 0.7045  Acc: 1.0000
#
# Epoch [29/30]
#   Train — Loss: 0.7620  Acc: 0.9965
#   Val   — Loss: 0.7052  Acc: 1.0000
#
# Epoch [30/30]
#   Train — Loss: 0.7610  Acc: 0.9963
#   Val   — Loss: 0.7052  Acc: 1.0000
# c:\Users\bayub\Documents\chord-classification\cnn.py:225: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(save_path))
# ========================================
# Test Accuracy : 1.0000
# Test Loss     : 0.7039
# Precision     : 1.0000
# Recall        : 1.0000
# F1 Score      : 1.0000
# ========================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       180
#            1       1.00      1.00      1.00       180
#            2       1.00      1.00      1.00       180
#            3       1.00      1.00      1.00       180
#            4       1.00      1.00      1.00       180
#            5       1.00      1.00      1.00       180
#            6       1.00      1.00      1.00       180
#            7       1.00      1.00      1.00       180
#            8       1.00      1.00      1.00       180
#            9       1.00      1.00      1.00       180
#           10       1.00      1.00      1.00       180
#           11       1.00      1.00      1.00       180
#           12       1.00      1.00      1.00       180
#           13       1.00      1.00      1.00       180
#           14       1.00      1.00      1.00       180
#           15       1.00      1.00      1.00       180
#           16       1.00      1.00      1.00       180
#           17       1.00      1.00      1.00       180
#           18       1.00      1.00      1.00       180
#           19       1.00      1.00      1.00       180
#           20       1.00      1.00      1.00       180
#           21       1.00      1.00      1.00       180
#           22       1.00      1.00      1.00       180
#           23       1.00      1.00      1.00       180
#           24       1.00      1.00      1.00       180
#           25       1.00      1.00      1.00       180
#           26       1.00      1.00      1.00       180
#           27       1.00      1.00      1.00       180
#           28       1.00      1.00      1.00       180
#           29       1.00      1.00      1.00       180
#           30       1.00      1.00      1.00       180
#           31       1.00      1.00      1.00       180
#           32       1.00      1.00      1.00       180
#           33       1.00      1.00      1.00       180
#           34       1.00      1.00      1.00       180
#           35       1.00      1.00      1.00       180
#           36       1.00      1.00      1.00       180
#           37       1.00      1.00      1.00       180
#           38       1.00      1.00      1.00       181
#           39       1.00      1.00      1.00       180
#           40       1.00      1.00      1.00       180
#           41       1.00      1.00      1.00       180
#           42       1.00      1.00      1.00       180
#           43       1.00      1.00      1.00       180
#           44       1.00      1.00      1.00       180
#           45       1.00      1.00      1.00       180
#           46       1.00      1.00      1.00       180
#           47       1.00      1.00      1.00       180
#
#     accuracy                           1.00      8641
#    macro avg       1.00      1.00      1.00      8641
# weighted avg       1.00      1.00      1.00      8641
